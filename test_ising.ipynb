# %%
import matplotlib.pyplot as plt
from IsingClass import Ising

# %%
ising = Ising(1000, 100_000, 0.5, 1, 0)

# %%
ising.monte_carlo()
# Out:
# Monte Carlo finished

# %%
plt.plot(ising.magnetizations)

# %%
plt.plot(ising.energies)
