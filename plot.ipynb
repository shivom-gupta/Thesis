# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('code/out.txt', delimiter='\t', names =  ['t', 'E', 'M'])

# %%
df.head()
# Out:
#    t      E      M
# 0  0 -0.998  1.000
# 1  1 -0.938  0.946
# 2  2 -0.886  0.882
# 3  3 -0.866  0.842
# 4  4 -0.850  0.794

# %%
plt.plot(df['t'][:1000], df.E[:1000])

# %%
plt.plot(df.t[:1000], df.M[:1000])
