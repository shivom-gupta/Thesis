# %%
import matplotlib.pyplot as plt
from ising import *

# %%
energies, magnetizations= monte_carlo_noconfig(100_000, 1, 1, 0, init_configuration(1000))

# %%
plt.plot(magnetizations)

# %%
plt.plot(energies)
